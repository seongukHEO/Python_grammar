# %%
import numpy as np
from matplotlib import pyplot as plt

import platfrom
from matplotlib import font_manager

if platform.system() == "Darwin":
    plt.rc('font', family='AppleGothic')
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 from matplotlib import pyplot as plt
# ----> 4 import platfrom
#       5 from matplotlib import font_manager
#       7 if platform.system() == "Darwin":
#
# ModuleNotFoundError: No module named 'platfrom'

# %% [markdown]
# Functional Programming Style

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 점찍기

# %%
plt.plot(3, 2, 'o', color='r')
plt.show()

# %% [markdown]
# 선 긋기

# %%
plt.plot([1,2,3], [4,5,1])
plt.show()

# %% [markdown]
# title과 label 추가하기

# %%
x= [5, 8, 10]
y = [12, 16, 6]
x2 = [6, 9, 11]
y2 = [6, 15, 7]

plt.plot(x,y)
plt.plot(x2, y2)
plt.title("TestPlot")
plt.xlabel("month")
plt.ylabel("price")
plt.show()

# %% [markdown]
# bar chart : 바 형식

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.title("BarChart")
# Out:
# Text(0.5, 1.0, 'BarChart')

# %%
plt.bar(x, y, label="Korea"),
plt.bar(x2, y2, label="US"),
plt.xlabel("age")
plt.ylabel("person")
plt.title("BarChart")
plt.legend()

# %% [markdown]
# 산점도(scatter plot)

# %%
plt.scatter(x, y)

# %%
plt.scatter(x, y, color="Red")

# %%
plt.scatter(x, y, color="Red", label="KOREA")
plt.scatter(x2, y2, color="blue", label="FRANCE")
plt.legend()

# %% [markdown]
# histogram

# %%
np.random.seed(0)
x = np.random.randn(1000)
x
# Out:
# array([ 1.76405235e+00,  4.00157208e-01,  9.78737984e-01,  2.24089320e+00,
#         1.86755799e+00, -9.77277880e-01,  9.50088418e-01, -1.51357208e-01,
#        -1.03218852e-01,  4.10598502e-01,  1.44043571e-01,  1.45427351e+00,
#         7.61037725e-01,  1.21675016e-01,  4.43863233e-01,  3.33674327e-01,
#         1.49407907e+00, -2.05158264e-01,  3.13067702e-01, -8.54095739e-01,
#        -2.55298982e+00,  6.53618595e-01,  8.64436199e-01, -7.42165020e-01,
#         2.26975462e+00, -1.45436567e+00,  4.57585173e-02, -1.87183850e-01,
#         1.53277921e+00,  1.46935877e+00,  1.54947426e-01,  3.78162520e-01,
#        -8.87785748e-01, -1.98079647e+00, -3.47912149e-01,  1.56348969e-01,
#         1.23029068e+00,  1.20237985e+00, -3.87326817e-01, -3.02302751e-01,
#        -1.04855297e+00, -1.42001794e+00, -1.70627019e+00,  1.95077540e+00,
#        -5.09652182e-01, -4.38074302e-01, -1.25279536e+00,  7.77490356e-01,
# ...

# %%
plt.hist(x, bins=30);

# %%
plt.xlabel('random')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
plt.hist(x)
plt.xlabel('random')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %% [markdown]
# OOP Style

# %%
np.random.randint(1, 11, 50)
# Out:
# array([ 3,  1,  3,  5,  5,  9,  5,  8,  6,  3,  4,  1,  8, 10,  7, 10,  9,
#         2,  8,  7,  9,  5,  4,  6,  3,  1,  2,  5,  1,  6,  9,  4, 10,  2,
#         6, 10,  1,  9,  2,  7, 10,  8,  2,  5, 10,  9,  7,  8,  6,  8])

# %%
x = np.random.randint(low=1, high=11, size=50)
y = x + np.random.randint(1, 5, size=x.size)

data = x + y
data
# Out:
# array([22, 15,  7, 11, 18, 22, 19, 20, 22, 21,  6, 15, 11, 17, 10, 16, 12,
#        16, 19, 21, 16,  3, 15, 22,  6, 13, 20, 13, 10, 17, 13, 18,  9, 15,
#        20,  4, 16, 12,  7, 11,  9,  3, 23, 16, 19,  5,  4, 21, 16, 22])

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(8,4))

ax1.scatter(x,y, color="Red", marker='o', edgecolor='k')
ax1.set_title('SCATTERPLOT')
ax1.set_xlabel("X axis")
ax1.set_ylabel("Y axis")

ax2.hist(data, bins=20)
ax2.set_title("HISTOGRAM")
# Out:
# Text(0.5, 1.0, 'HISTOGRAM')

# %% [markdown]
# Imshow : image data처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 inshow로 표시

# %%
from sklearn.datasets import load_digits

# %%
load_digits()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 load_digits()
#
# NameError: name 'load_digits' is not defined

# %%
from sklearn.datasets import load_digits

digits = load_digits()  # 이 코드를 실행해야 함
print(digits.data.shape)  # 데이터의 크기 확인
# Out:
# (1797, 64)

# %%
digits()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 digits()
#
# TypeError: 'Bunch' object is not callable

# %%
load_digits()
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
x = load_digits()
img = x["images"]
img
# Out:
# array([[[ 0.,  0.,  5., ...,  1.,  0.,  0.],
#         [ 0.,  0., 13., ..., 15.,  5.,  0.],
#         [ 0.,  3., 15., ..., 11.,  8.,  0.],
#         ...,
#         [ 0.,  4., 11., ..., 12.,  7.,  0.],
#         [ 0.,  2., 14., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  6., ...,  0.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ...,  5.,  0.,  0.],
#         [ 0.,  0.,  0., ...,  9.,  0.,  0.],
#         [ 0.,  0.,  3., ...,  6.,  0.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.]],
#
#        [[ 0.,  0.,  0., ..., 12.,  0.,  0.],
#         [ 0.,  0.,  3., ..., 14.,  0.,  0.],
#         [ 0.,  0.,  8., ..., 16.,  0.,  0.],
#         ...,
#         [ 0.,  9., 16., ...,  0.,  0.,  0.],
#         [ 0.,  3., 13., ..., 11.,  5.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.]],
#
#        ...,
#
#        [[ 0.,  0.,  1., ...,  1.,  0.,  0.],
# ...

# %%
img.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 img.shape()
#
# TypeError: 'tuple' object is not callable

# %%
img.shape
# Out:
# (1797, 8, 8)

# %%
img = x["images"][0]
img
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
img.shape
# Out:
# (8, 8)

# %%
plt.imshow(img, cmap="gray")
plt.xticks([])
plt.yticks([])
# Out:
# ([], [])
